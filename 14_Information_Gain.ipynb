# %% [markdown]
# # Information Gain

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC

from math import log, e

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# from MLearningUtils import MLearningUtils as util

import MLearningUtils as mlUtil
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.DataFrame()

df = pd.read_csv('data/hospitals.csv')
# print(df.shape)
# df.head(3)

# %%
categorical_features = ['Rating.Mortality','Rating.Readmission', 'Procedure.Pneumonia.Value','Procedure.Pneumonia.Quality']

util = mlUtil.MLearningUtils()
result_scores = util.get_information_gain(df,'Rating.Overall')

result_scores
# Out:
# Getting entropy from dtypes('object') features: 100%|██████████| 19/19 [00:04<00:00,  4.36it/s]
#                                     target_attribute  entropy_target  \
# 0                     (Rating.Overall,Facility.Name)        2.393355
# 1                     (Rating.Overall,Facility.City)        2.393355
# 6                (Rating.Overall,Rating.Readmission)        2.393355
# 7                 (Rating.Overall,Rating.Experience)        2.393355
# 5                     (Rating.Overall,Rating.Safety)        2.393355
# 4                  (Rating.Overall,Rating.Mortality)        2.393355
# 13  (Rating.Overall,Procedure.Heart Failure.Quality)        2.393355
# 14    (Rating.Overall,Procedure.Heart Failure.Value)        2.393355
# 9                 (Rating.Overall,Rating.Timeliness)        2.393355
# 8              (Rating.Overall,Rating.Effectiveness)        2.393355
# 10                   (Rating.Overall,Rating.Imaging)        2.393355
# ...

# %%
util = mlUtil.MLearningUtils()

# util.check_missing_data(df)


# test1 = df['Rating.Overall']

# pd.Series


test2 = util.get_entropy(df['Rating.Overall'])

test2
# Out:
# 2.3933551471491725
